# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/StudentPerformanceFactors.csv')

# %%
df.shape
# Out:
# (6607, 20)

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
df.tail()
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 6602                         No            7               76
# 6603                         No            8               81
# 6604                        Yes            6               65
# 6605                        Yes            6               91
# 6606                        Yes            9               94
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 6602           Medium             Yes                  1          High
# ...

# %%
df.dtypes
# Out:
# Hours_Studied                  int64
# Attendance                     int64
# Parental_Involvement          object
# Access_to_Resources           object
# Extracurricular_Activities    object
# Sleep_Hours                    int64
# Previous_Scores                int64
# Motivation_Level              object
# Internet_Access               object
# Tutoring_Sessions              int64
# Family_Income                 object
# Teacher_Quality               object
# School_Type                   object
# Peer_Influence                object
# Physical_Activity              int64
# Learning_Disabilities         object
# Parental_Education_Level      object
# Distance_from_Home            object
# Gender                        object
# Exam_Score                     int64
# dtype: object

# %%
df  = df.dropna()
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
df_cleaned = df.dropna()
df_cleaned.isnull().sum()
# Out:
# Hours_Studied                 0
# Attendance                    0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# Teacher_Quality               0
# School_Type                   0
# Peer_Influence                0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      0
# Distance_from_Home            0
# Gender                        0
# Exam_Score                    0
# dtype: int64

# %% [markdown]
# Univariate analysis

# %%
numerical_columns = ['Hours_Studied', 'Attendance', 'Sleep_Hours', 'Previous_Scores', 'Tutoring_Sessions','Exam_Score']  # Update with your actual numerical columns
for column in numerical_columns:
    df[column] = pd.to_numeric(df[column], errors='coerce')
df_cleaned = df[numerical_columns].dropna()
df_cleaned[numerical_columns].describe()
# Out:
# <ipython-input-103-a98c1bee44be>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce')
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6378.000000  6378.000000  6378.000000      6378.000000
# mean       19.977109    80.020853     7.034964        75.066165
# std         5.985460    11.550723     1.468033        14.400389
# min         1.000000    60.000000     4.000000        50.000000
# 25%        16.000000    70.000000     6.000000        63.000000
# 50%        20.000000    80.000000     7.000000        75.000000
# 75%        24.000000    90.000000     8.000000        88.000000
# max        44.000000   100.000000    10.000000       100.000000
#
# ...

# %%
df.dtypes
# Out:
# Hours_Studied                  int64
# Attendance                     int64
# Parental_Involvement          object
# Access_to_Resources           object
# Extracurricular_Activities    object
# Sleep_Hours                    int64
# Previous_Scores                int64
# Motivation_Level              object
# Internet_Access               object
# Tutoring_Sessions              int64
# Family_Income                 object
# Teacher_Quality               object
# School_Type                   object
# Peer_Influence                object
# Physical_Activity              int64
# Learning_Disabilities         object
# Parental_Education_Level      object
# Distance_from_Home            object
# Gender                        object
# Exam_Score                     int64
# dtype: object

# %%
numerical_columns = ['Exam_Score']
df_cleaned[numerical_columns].hist(figsize=(10, 8), bins=20)
plt.suptitle("Histograms for Numerical Columns")
# Out:
# Text(0.5, 0.98, 'Histograms for Numerical Columns')

# %%
numerical_columns = ['Tutoring_Sessions']
df_cleaned[numerical_columns].hist(figsize=(10, 8), bins=20)
plt.suptitle("Histograms for Numerical Columns")
# Out:
# Text(0.5, 0.98, 'Histograms for Numerical Columns')

# %%
numerical_columns = ['Previous_Scores']
df_cleaned[numerical_columns].hist(figsize=(10, 8), bins=20)
plt.suptitle("Histograms for Numerical Columns")
# Out:
# Text(0.5, 0.98, 'Histograms for Numerical Columns')

# %%
numerical_columns = ['Sleep_Hours']
df_cleaned[numerical_columns].hist(figsize=(10, 8), bins=20)
plt.suptitle("Histograms for Numerical Columns")
# Out:
# Text(0.5, 0.98, 'Histograms for Numerical Columns')

# %%
numerical_columns = ['Attendance']
df_cleaned[numerical_columns].hist(figsize=(10, 8), bins=20)
plt.suptitle("Histograms for Numerical Columns")
# Out:
# Text(0.5, 0.98, 'Histograms for Numerical Columns')

# %%
numerical_columns = ['Hours_Studied']
df_cleaned[numerical_columns].hist(figsize=(10, 8), bins=20)
plt.suptitle("Histograms for Numerical Columns")
# Out:
# Text(0.5, 0.98, 'Histograms for Numerical Columns')

# %%
df['Parental_Involvement'].value_counts()
# Out:
# Parental_Involvement
# Medium    3251
# High      1836
# Low       1291
# Name: count, dtype: int64

# %%
plt.figure(figsize=(16, 13))


sns.countplot(y="Parental_Involvement", data=df)
plt.title(f"Bar Plot of Parental_Involvement")
plt.show()

# %%
plt.figure(figsize=(16, 13))


sns.countplot(y="Access_to_Resources", data=df)
plt.title(f"Bar Plot of Parental_Involvement")
plt.show()

# %%
plt.figure(figsize=(16, 13))


sns.countplot(y="Internet_Access", data=df)
plt.title(f"Bar Plot of Parental_Involvement")
plt.show()

# %%
plt.figure(figsize=(16, 13))


sns.countplot(y="Family_Income", data=df)
plt.title(f"Bar Plot of Parental_Involvement")
plt.show()

# %%
df_cleaned
# Out:
#       Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# 0                23          84            7               73
# 1                19          64            8               59
# 2                24          98            7               91
# 3                29          89            8               98
# 4                19          92            6               65
# ...             ...         ...          ...              ...
# 6602             25          69            7               76
# 6603             23          76            8               81
# 6604             20          90            6               65
# 6605             10          86            6               91
# 6606             15          67            9               94
#
#       Tutoring_Sessions  Exam_Score
# 0                     0          67
# 1                     2          61
# 2                     2          74
# 3                     1          71
# ...

# %%
categorical_columns = ['Parental_Education_Level']
college_type_counts = df['Parental_Education_Level'].value_counts()
plt.figure(figsize=(7, 7))
plt.pie(college_type_counts, labels=college_type_counts.index, autopct='%1.1f%%', startangle=90, colors=['grey', 'Red','Blue'])
plt.title('Parental_Education_Level')
plt.axis('equal')
# Out:
# (-1.099999933291981,
#  1.0999988417791786,
#  -1.099999981034778,
#  1.0999999990968943)

# %%
print(college_type_counts)
print(college_type_counts.index)
print(college_type_counts.values)
# Out:
# Parental_Education_Level
# High School     3159
# College         1939
# Postgraduate    1280
# Name: count, dtype: int64
# Index(['High School', 'College', 'Postgraduate'], dtype='object', name='Parental_Education_Level')
# [3159 1939 1280]

# %%
categorical_columns = ['Gender']
college_type_counts = df['Gender'].value_counts()
plt.figure(figsize=(7, 7))
plt.pie(college_type_counts, labels=college_type_counts.index, autopct='%1.1f%%', startangle=90, colors=['grey', 'Red','Blue'])
plt.title('Gender')
plt.axis('equal')
# Out:
# (-1.099998466645002,
#  1.0999910302881757,
#  -1.0999999689400783,
#  1.099999998520956)

# %%
df['Hours_Studied'] = pd.to_numeric(df['Hours_Studied'], errors='coerce')
df['Exam_Score'] = pd.to_numeric(df['Exam_Score'], errors='coerce')

correlation_matrix = df[['Exam_Score', 'Hours_Studied']].corr()
correlation_matrix
# Out:
#                Exam_Score  Hours_Studied
# Exam_Score       1.000000       0.445104
# Hours_Studied    0.445104       1.000000

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Hours_Studied', y='Exam_Score', data=df)
plt.title('Hours_Studied vs Exam_Score')
# Out:
# Text(0.5, 1.0, 'Hours_Studied vs Exam_Score')

# %%
plt.figure(figsize=(4, 6))
sns.boxplot(x='Gender', y='Exam_Score', data=df)
plt.title('Exam_Score by Gender')
# Out:
# Text(0.5, 1.0, 'Exam_Score by Gender')

# %%
numerical_columns = ['Exam_Score', 'Previous_Scores', 'Attendance', 'Hours_Studied']


correlation_matrix = df[numerical_columns].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap of Numerical Features")
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap of Numerical Features')
